# %% [markdown]
# ------------------
# # Data Cleaning
# -----------------

# %%
# Install to run code in notebook

# !pip install plotly.express
# !pip install meteostat
# Out:
# Requirement already satisfied: plotly.express in c:\users\sorem\miniconda3\lib\site-packages (0.4.1)
# Requirement already satisfied: pandas>=0.20.0 in c:\users\sorem\miniconda3\lib\site-packages (from plotly.express) (2.3.3)
# Requirement already satisfied: plotly>=4.1.0 in c:\users\sorem\miniconda3\lib\site-packages (from plotly.express) (6.4.0)
# Requirement already satisfied: statsmodels>=0.9.0 in c:\users\sorem\miniconda3\lib\site-packages (from plotly.express) (0.14.5)
# Requirement already satisfied: scipy>=0.18 in c:\users\sorem\miniconda3\lib\site-packages (from plotly.express) (1.16.3)
# Requirement already satisfied: patsy>=0.5 in c:\users\sorem\miniconda3\lib\site-packages (from plotly.express) (1.0.2)
# Requirement already satisfied: numpy>=1.11 in c:\users\sorem\miniconda3\lib\site-packages (from plotly.express) (2.3.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\sorem\miniconda3\lib\site-packages (from pandas>=0.20.0->plotly.express) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\sorem\miniconda3\lib\site-packages (from pandas>=0.20.0->plotly.express) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\sorem\miniconda3\lib\site-packages (from pandas>=0.20.0->plotly.express) (2025.2)
# Requirement already satisfied: narwhals>=1.15.1 in c:\users\sorem\miniconda3\lib\site-packages (from plotly>=4.1.0->plotly.express) (2.10.2)
# Requirement already satisfied: packaging in c:\users\sorem\miniconda3\lib\site-packages (from plotly>=4.1.0->plotly.express) (25.0)
# Requirement already satisfied: six>=1.5 in c:\users\sorem\miniconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas>=0.20.0->plotly.express) (1.17.0)
# Requirement already satisfied: meteostat in c:\users\sorem\miniconda3\lib\site-packages (1.7.6)
# Requirement already satisfied: pandas>=2 in c:\users\sorem\miniconda3\lib\site-packages (from meteostat) (2.3.3)
# Requirement already satisfied: pytz in c:\users\sorem\miniconda3\lib\site-packages (from meteostat) (2025.2)
# Requirement already satisfied: numpy in c:\users\sorem\miniconda3\lib\site-packages (from meteostat) (2.3.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\sorem\miniconda3\lib\site-packages (from pandas>=2->meteostat) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\sorem\miniconda3\lib\site-packages (from pandas>=2->meteostat) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\sorem\miniconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas>=2->meteostat) (1.17.0)

# %%
# Libraries used for Data Cleaning
import pandas as pd
import re

# %%
df = pd.read_excel("../data/raw/GSAF5.xls")
df.head()
# Out:
#              Date    Year        Type     Country                  State  \
# 0    14th October  2025.0  Unprovoked    Columbia   Bolivar, del Isolate
# 1    11th October  2025.0  Unprovoked   Australia             Queensland
# 2     7th October  2025.0  Unprovoked   Australia        South Australia
# 3  29th September  2025.0  Unprovoked         USA         Off California
# 4  27th September  2025.0    Provoked  Costa Rica                    NaN
#
#                          Location               Activity                Name  \
# 0               Catagena Province   Swimming with sharks          Male child
# 1  Cook Esplanade Thursday Island       Fishing/swimming          Samuel Nai
# 2                 Kangaroo Island                Surfing        Lee Berryman
# 3                 Catalina Island               Swimming  Christopher Murray
# 4                   Cocos Islands  Diving-Tagging sharks  Dr. Mauricio Hoyos
#
#   Sex  Age  ...             Species   \
# 0   M   14  ...         Nurse shark
# 1   M   14  ...  Tiger or Bull shark
# 2   M  50+  ...       Bronze whaler?
# 3   M   54  ...   unknown 1.2m shark
# 4   M   48  ...       Tiger shark 4m
#
#                                           Source  pdf href formula href  \
# 0  Kevin McMurray Trackingsharks.com Andy Currie  NaN          NaN  NaN
# 1              Kevin McMurray Trackingsharks.com  NaN          NaN  NaN
# 2              Kevin McMurray Trackingsharks.com  NaN          NaN  NaN
# 3  Todd Smith: Kevin McMurray Trackingsharks.com  NaN          NaN  NaN
# 4  Todd Smith: Kevin McMurray Trackingsharks.com  NaN          NaN  NaN
#
#   Case Number Case Number.1 original order Unnamed: 21 Unnamed: 22
# 0         NaN           NaN            NaN         NaN         NaN
# 1         NaN           NaN            NaN         NaN         NaN
# 2         NaN           NaN            NaN         NaN         NaN
# 3         NaN           NaN            NaN         NaN         NaN
# 4         NaN           NaN            NaN         NaN         NaN
#
# [5 rows x 23 columns]

# %% [markdown]
# ## State and Location Cleaning

# %%
df['State'].value_counts()
# Out:
# State
# Florida                                  1192
# New South Wales                           522
# Queensland                                353
# Hawaii                                    344
# California                                325
#                                          ...
# Chatham Islands, east of New  Zealand       1
# Clearwater Bay                              1
# Aichi Prefecture                            1
# Tafea Province                              1
# Moala Island                                1
# Name: count, Length: 939, dtype: int64

# %%
df['Location'].value_counts()
# Out:
# Location
# New Smyrna Beach, Volusia County       191
# Daytona Beach, Volusia County           31
# Ponce Inlet, Volusia County             28
# Myrtle Beach, Horry County              22
# Melbourne Beach, Brevard County         20
#                                       ...
# Punaluu                                  1
# Te Arai Point                            1
# Kalihiwai Beach, Kauai                   1
# 5 nm off Cervantes                       1
# Below the English fort, Trincomalee      1
# Name: count, Length: 4598, dtype: int64

# %%
#Must Clean the messy geographical text inluded in the Location and State Column

# Fill missing values
df['Location'] = df['Location'].fillna('Unknown')
# Replace empty states with Unknown
df['State'] = df['State'].replace('', 'Unknown')


# Regex pattern to remove numbers and units
pattern = r'\b(\d+|miles|mi|km|kilometers)\b'

unwanted_words = ['miles', 'mi', 'km', 'kilometers', 'islands', 'near','nm', 'off', 
                  'below', 'the', 'of', 'east of', 'west of', 'south of',
                   'between', '&' , 'north of', 'ºN', 'ºS', 'ºW', 'ºE']                    
pattern = r'\b(?:' + '|'.join(unwanted_words) + r'|\d+)\b'

# Clean the Location column
df['location_clean'] = (
    df['Location']
    .str.replace(pattern, '', regex=True, flags=re.IGNORECASE)  # remove numbers & units
    .str.replace(r'\s+', ' ', regex=True)  # remove extra spaces
    .str.strip()
)

df['state_clean'] = (
    df['State']
    .str.replace(pattern, '', regex=True, flags=re.IGNORECASE)  # remove numbers & units
    .str.replace(r'\s+', ' ', regex=True)  # remove extra spaces
    .str.strip()
)
df['location_clean'] = df['location_clean'].replace('', 'Unknown').fillna('Unknown')

df['state_clean'] = df['state_clean'].replace('', 'Unknown').fillna('Unknown')


# Print the result
print(df[['Location', 'State', 'location_clean', 'state_clean']])
# Out:
#                                  Location                  State  \
# 0                       Catagena Province   Bolivar, del Isolate
# 1          Cook Esplanade Thursday Island             Queensland
# 2                         Kangaroo Island        South Australia
# 3                         Catalina Island         Off California
# 4                           Cocos Islands                    NaN
# ...                                   ...                    ...
# 7045                          Roebuck Bay      Western Australia
# 7046                              Unknown      Western Australia
# 7047                       Ocracoke Inlet         North Carolina
# 7048                 Panama Bay 8ºN, 79ºW                    NaN
# 7049  Below the English fort, Trincomalee       Eastern Province
#
#                       location_clean           state_clean
# 0                  Catagena Province  Bolivar, del Isolate
# 1     Cook Esplanade Thursday Island            Queensland
# 2                    Kangaroo Island       South Australia
# 3                    Catalina Island            California
# 4                              Cocos               Unknown
# ...                              ...                   ...
# 7045                     Roebuck Bay     Western Australia
# 7046                         Unknown     Western Australia
# 7047                  Ocracoke Inlet        North Carolina
# 7048            Panama Bay 8ºN, 79ºW               Unknown
# 7049       English fort, Trincomalee      Eastern Province
#
# [7050 rows x 4 columns]

# %%
df['state_clean'].value_counts()
# Out:
# state_clean
# Florida                 1193
# New South Wales          524
# Unknown                  486
# Queensland               354
# Hawaii                   346
#                         ...
# Aichi Prefecture           1
# Tafea Province             1
# Kagoshima Prefecture       1
# Costa Blanca               1
# Moala Island               1
# Name: count, Length: 891, dtype: int64

# %%
#summary for categorical variables
df[['state_clean', 'State']].describe()
# Out:
#        state_clean    State
# count         7050     6564
# unique         891      939
# top        Florida  Florida
# freq          1193     1192
